# %% [markdown]
# # Experimento 2 Mobilidade com RPL-UDP-TSCH
#
# Experimento com Mobilidade.

# %%
import sys, os
from pathlib import Path

project_path = os.path.abspath(os.path.join(os.getcwd(), "../../../../.."))  # Ajuste conforme a localização do notebook
if project_path not in sys.path:
    sys.path.insert(0, project_path)
    
from pylib import visual
from pylib import specific_nb_plot

log_path = Path("./cooja.log")          # arquivo de log de entrada
csv_full  = Path("cooja_metrics.csv")   # métricas individuais
csv_means = Path("cooja_means.csv")     # médias por mote

visual.plot_network_from_json("../../../../model/mobile/ex2.json")

specific_nb_plot.process_log2(log_path, csv_full, csv_means)
# Out:
# === MÉDIAS POR MOTE ===
#               node  cpu_mj  total_mj  latency_ms  volume_B  response_ms  throughput_bps
#    fd00::202:2:2:2   26.27     55.58     1525.83   6839.26      3784.27         3051.63
#    fd00::203:3:3:3   33.88     95.41     1938.17   5507.92      5208.51         3366.78
#    fd00::204:4:4:4   20.29     39.38     2981.75   4877.77      6252.22         3709.06
#    fd00::205:5:5:5   20.95     45.26     4439.43   4781.30      7949.75         3803.53
#    fd00::206:6:6:6   36.25     94.27     2790.66   5136.43      6176.10         3612.75
#    fd00::207:7:7:7   47.86     87.84      776.55   4856.27      2796.14         4051.95
#    fd00::208:8:8:8   20.07     48.10     1572.91   4669.41      3940.27         3925.43
#    fd00::209:9:9:9   41.63    116.23      149.79   3538.86      3201.19      1304182.01
#    fd00::20a:a:a:a   61.54    243.55     1065.12   2671.71      5288.75         8754.89
#    fd00::20b:b:b:b   64.56    489.56     2113.56    344.00      5745.89        53413.22
#    fd00::20d:d:d:d   46.83    322.08     2151.08    453.00      6071.17        40081.33
#    fd00::20e:e:e:e  324.12   1633.38     2301.12    672.00     10404.12        60217.38
# fd00::210:10:10:10  126.17    597.17     4391.67    846.00      4091.83       160351.33
# fd00::211:11:11:11   30.62     85.73     5359.22   3492.59      9479.70        23489.78
# fd00::212:12:12:12  143.40    214.60     2793.40    955.20      3591.40       480672.60
# fd00::213:13:13:13  180.09    670.45     4989.45    722.18      6298.55       131035.82
