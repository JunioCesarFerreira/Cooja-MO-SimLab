# %% [markdown]
# # Experimento 2 Mobilidade com RPL-UDP
#
# Experimento com Mobilidade.

# %%
import sys, os
from pathlib import Path

project_path = os.path.abspath(os.path.join(os.getcwd(), "../../../../.."))  # Ajuste conforme a localização do notebook
if project_path not in sys.path:
    sys.path.insert(0, project_path)
    
from pylib import visual
from pylib import specific_nb_plot

log_path = Path("./cooja.log")          # arquivo de log de entrada
csv_full  = Path("cooja_metrics.csv")   # métricas individuais
csv_means = Path("cooja_means.csv")     # médias por mote

visual.plot_network_from_json("../../../../model/mobile/ex2.json")

specific_nb_plot.process_log1(log_path, csv_full, csv_means)
# Out:
# === MÉDIAS POR MOTE ===
#               node  rtt_latency  r2n_latency  n2r_latency   rssi  radio_rx_energy_mj  radio_tx_energy_mj  cpu_energy_mj  lost_packets_r2n  lost_packets_n2r
#    fd00::202:2:2:2        43.87 1.800700e+02 1.817862e+19 -82.77              203.47                1.34          18.06              0.01              0.01
#    fd00::203:3:3:3       150.84 1.827647e+19 5.751000e+02 -87.46              215.16                0.94          19.12             36.93             55.14
#    fd00::204:4:4:4       226.48 3.234100e+02 2.277376e+17 -87.73              215.30                0.44          19.18             17.34             24.53
#    fd00::205:5:5:5       286.41 5.969646e+18 4.466800e+02 -76.78              204.43                0.27          18.27              4.89              8.72
#    fd00::206:6:6:6       124.00 2.539600e+02 1.779759e+19 -85.75              204.73                0.11          18.11              1.53             12.02
#    fd00::207:7:7:7         0.00 0.000000e+00 4.954000e+01   0.00              210.63                0.01          19.06            178.14            178.14
#    fd00::208:8:8:8         0.00 0.000000e+00 1.844674e+19   0.00              203.71                0.00          18.16            177.39            177.39
#    fd00::209:9:9:9        46.21 1.839249e+19 3.553200e+02 -89.71              204.88                1.61          18.06              0.00              0.04
#    fd00::20a:a:a:a       119.15 1.616741e+19 2.326600e+02 -90.74              200.66                1.11          18.16              0.02             12.70
#    fd00::20b:b:b:b       209.20 4.583700e+02 1.778399e+19 -93.72              210.01                0.25          19.23             22.84             40.89
#    fd00::20c:c:c:c       341.18 3.107700e+02 3.563200e+02 -50.71              199.37                0.02          18.29             12.03             19.18
#    fd00::20d:d:d:d       245.78 1.678985e+19 5.912000e+02 -42.87              210.05                0.07          19.23             29.36             35.41
#    fd00::20e:e:e:e       152.45 1.010000e+02 1.323200e+02 -61.87             1026.90                1.10          93.71             50.55            113.19
#    fd00::20f:f:f:f       341.57 4.072400e+02 2.158800e+02 -63.26              238.56                0.03          20.90             40.94             67.31
# fd00::210:10:10:10       252.82 2.955500e+02 1.686800e+02 -47.77             1751.68                1.95         159.68            150.73            179.77
# fd00::211:11:11:11       311.04 7.378698e+18 5.494000e+02 -76.16              484.06                0.48          44.08             21.04             59.70
# fd00::212:12:12:12       349.42 5.950600e+02 1.676977e+18 -49.70             1766.91                1.76         161.55            113.27            160.88
# fd00::213:13:13:13       394.50 3.002400e+02 4.748200e+02 -80.56             1659.12                0.97         151.44            104.32            158.38
