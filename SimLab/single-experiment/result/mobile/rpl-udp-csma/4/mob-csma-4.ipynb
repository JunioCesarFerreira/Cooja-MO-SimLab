# %% [markdown]
# # Experimento 4 Mobilidade com RPL-UDP
#
# Experimento com Mobilidade: Neste experimento, uma pequena rede de motes estáticos é posicionada para cobrir uma trajetória sobre um retângulo.

# %%
import sys, os
from pathlib import Path

project_path = os.path.abspath(os.path.join(os.getcwd(), "../../../../.."))  # Ajuste conforme a localização do notebook
if project_path not in sys.path:
    sys.path.insert(0, project_path)
    
from pylib import visual
from pylib import specific_nb_plot

log_path = Path("./cooja.log")          # arquivo de log de entrada
csv_full  = Path("cooja_metrics.csv")   # métricas individuais
csv_means = Path("cooja_means.csv")     # médias por mote

visual.plot_network_from_json("../../../../model/mobile/ex4.json")

specific_nb_plot.process_log1(log_path, csv_full, csv_means)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 17
#      13 csv_means = Path("cooja_means.csv")     # médias por mote
#      15 visual.plot_network_from_json("../../../../model/mobile/ex4.json")
# ---> 17 specific_nb_plot.process_log1(log_path, csv_full, csv_means)
#
# File c:\Users\jcf_s\source\git\Cooja-MO-SimLab\SimLab\pylib\specific_nb_plot.py:8, in process_log1(log_path, csv_full_output, csv_means_output)
#       6 def process_log1(log_path: Path, csv_full_output: Path, csv_means_output: Path):
#       7     # -------------------------- DataFrame bruto --------------------------------
# ----> 8     df = data_analysis.convert_log_to_csv(log_path, csv_full_output)
#      10     # Quantidades de pacotes perdidos
#      11     df["lost_packets_r2n"] = df["server_sent"] - df["total_received"]
#
# File c:\users\jcf_s\source\git\cooja-mo-simlab\simlab\pylib\data_analysis.py:14, in convert_log_to_csv(log_path, csv_output)
#      11 # ---------------------- Leitura + Extração JSON ----------------------------
#      12 rows = []
# ---> 14 with log_path.open(encoding="utf-8") as f:
#      15     for line in f:
#      16         m = json_pattern.search(line)
#
# File c:\Users\jcf_s\AppData\Local\Programs\Python\Python312\Lib\pathlib.py:1013, in Path.open(self, mode, buffering, encoding, errors, newline)
#    1011 if "b" not in mode:
#    1012     encoding = io.text_encoding(encoding)
# -> 1013 return io.open(self, mode, buffering, encoding, errors, newline)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'cooja.log'
